# %%
import torch
import torchvision
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
from torch.nn import Conv2d, MaxPool2d, Flatten, Linear, Sigmoid, Softmax
import torch.nn.utils.prune as prune 
from torch.optim import Adam
import torch.nn.functional as F
from torchsummary import summary
import time
import matplotlib.pyplot as plt
from ptflops import get_model_complexity_info
from thop import profile

# %%
import numpy as np

# %%
import cv2

# %%
from thop import profile

# %%
def read_image(file):
    feat, label = [], []
    with open(file) as f:
        for i in f:
            img_info = i.split(" ")
            
            img_name = img_info[0]
            img = cv2.imread(img_name, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (32,32))
            img_feat = img / 255.0
            img_feat = np.expand_dims(img_feat, axis=0)
            feat.append(img_feat)
            
            img_label = int(img_info[-1])
            onehot = np.zeros(50)
            onehot[img_label] = 1
            label.append(onehot)
            
        return np.array(feat), np.array(label)

# %%
# %%time
train_img, train_label = read_image("train.txt")
val_img, val_label = read_image("val.txt")
test_img, test_label = read_image("test.txt")
# Out:
# CPU times: total: 40.3 s
# Wall time: 41.6 s

# %%
def create_dataloader(img, label, batchsize):
    feat_tensor = torch.tensor(img, dtype=torch.float32)
    label_tensor = torch.tensor(label, dtype=torch.float32)
    dataset = TensorDataset(feat_tensor, label_tensor)
    dataloader = DataLoader(dataset, batch_size=batchsize, shuffle=True)
    return dataloader

# %%
train_dataloader = create_dataloader(train_img, train_label, batchsize=32)
val_dataloader = create_dataloader(val_img, val_label, batchsize=32)
test_dataloader = create_dataloader(test_img, test_label, batchsize=32)

# %% [markdown]
# # Pytorch version

# %%
class lenet5(nn.Module):
    def __init__(self):
        super(lenet5,self).__init__()
        self.conv1 = Conv2d(kernel_size=5, in_channels=1, out_channels=6)
        self.sigmoid1 = Sigmoid()
        self.maxpool1 = MaxPool2d(kernel_size=2)
        self.conv2 = Conv2d(kernel_size=5, in_channels=6, out_channels=16)
        self.sigmoid2 = Sigmoid()
        self.maxpool2 = MaxPool2d(kernel_size=2)
        self.flatten = Flatten()
        self.linear1 = Linear(in_features=5*5*16, out_features=120)
        self.sigmoid3 = Sigmoid()
        self.linear2 = Linear(in_features=120, out_features=84)
        self.sigmoid4 = Sigmoid()
        self.linear3 = Linear(in_features=84, out_features=50)
        self.softmax = Softmax(dim=1)
    def forward(self,x):
        x = self.conv1(x)
        x = self.sigmoid1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.sigmoid2(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.linear1(x)
        x = self.sigmoid3(x)
        x = self.linear2(x)
        x = self.sigmoid4(x)
        x = self.linear3(x)
        x = self.softmax(x)
        return x

# %%
# load the best model
model = lenet5()
model.load_state_dict(torch.load("hw3_best_model_pytorch.pth"))
# Out:
# <All keys matched successfully>

# %%
# prune the model
parameters_to_prune = (
    (model.conv1, 'weight'),
    (model.conv2, 'weight'),
    (model.linear1, 'weight'),
    (model.linear2, 'weight'),
    (model.linear3, 'weight')
)

prune.global_unstructured(
    parameters_to_prune,
    pruning_method=prune.L1Unstructured,
    amount=0.2,
)

# %%
prune.remove(model.conv1, 'weight')
prune.remove(model.conv2, 'weight')
prune.remove(model.linear1, 'weight')
prune.remove(model.linear2, 'weight')
prune.remove(model.linear3, 'weight')
# Out:
# Linear(in_features=84, out_features=50, bias=True)

# %%
epochs = 25
model = model.to("cuda")
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)
loss_fn = nn.CrossEntropyLoss(reduction="sum")

# %%
total_train_step = 0
total_val_step = 0
best_acc_loss = 100
train_acc_epoch, train_loss_epoch = [],[]
val_acc_epoch, val_loss_epoch = [],[]

for epoch in range(epochs):
    # training
    total_train_acc = 0
    total_train_loss = 0
    
    for data in train_dataloader:
        imgs, targets = data
        imgs = imgs.to("cuda:0")
        targets = targets.to("cuda:0")

        optimizer.zero_grad()
        output = model(imgs)
        loss = loss_fn(output, targets) # a whole batch loss
        total_train_loss += loss.item()
        accuracy = (output.argmax(1) == targets.argmax(1)).sum() # top1 accuracy
        total_train_acc += accuracy.item()
        loss.backward()
        optimizer.step()

        total_train_step += 1
        if total_train_step % 100 == 0:
            print("Times of training:{}, Training Loss:{}".format(total_train_step, loss/len(targets)))
    train_acc_epoch.append(total_train_acc/len(train_dataloader.dataset))
    train_loss_epoch.append(total_train_loss/len(train_dataloader.dataset))
    # validation
    total_val_loss = 0
    total_val_acc = 0

    with torch.no_grad():
        for data in val_dataloader:
            imgs, targets = data
            imgs = imgs.to("cuda:0")
            targets = targets.to("cuda:0")
            output = model(imgs)
            loss = loss_fn(output, targets) # a whole batch loss
            total_val_loss += loss.item()
            val_acc = (output.argmax(1) == targets.argmax(1)).sum()
            total_val_acc += val_acc.item()

    val_acc_epoch.append(total_val_acc/len(val_dataloader.dataset))
    val_loss_epoch.append(total_val_loss/len(val_dataloader.dataset))

    if total_val_loss/len(val_dataloader.dataset) < best_acc_loss:
        best_acc_loss = total_val_loss/len(val_dataloader.dataset)
        best_weights = model.state_dict()
    print("Validation loss:{}, Validation accuracy:{}".format(total_val_loss/len(val_dataloader.dataset), total_val_acc/len(val_dataloader.dataset)))
    total_val_step += 1

torch.save(best_weights, "hw3_best_model_pytorch_pruning.pth")
# Out:
# Times of training:100, Training Loss:3.876918077468872
# Times of training:200, Training Loss:3.867001533508301
# Times of training:300, Training Loss:3.8758225440979004
# Times of training:400, Training Loss:3.902374267578125
# Times of training:500, Training Loss:3.916672945022583
# Times of training:600, Training Loss:3.864980697631836
# Times of training:700, Training Loss:3.8076860904693604
# Times of training:800, Training Loss:3.836282730102539
# Times of training:900, Training Loss:3.8598804473876953
# Times of training:1000, Training Loss:3.8822150230407715
# Times of training:1100, Training Loss:3.8142316341400146
# Times of training:1200, Training Loss:3.848484754562378
# Times of training:1300, Training Loss:3.867812156677246
# Times of training:1400, Training Loss:3.889688491821289
# Times of training:1500, Training Loss:3.858461618423462
# Times of training:1600, Training Loss:3.895150661468506
# Times of training:1700, Training Loss:3.895061492919922
# Times of training:48700, Training Loss:3.8343448638916016
# Times of training:48800, Training Loss:3.8427562713623047
# Times of training:48900, Training Loss:3.813749313354492
# Times of training:49000, Training Loss:3.910874843597412
# Times of training:49100, Training Loss:3.8795382976531982
# Times of training:49200, Training Loss:3.8341445922851562
# Times of training:49300, Training Loss:3.7611570358276367
# Times of training:49400, Training Loss:3.8197691440582275
# Validation loss:3.8577836545308433, Validation accuracy:0.08666666666666667

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(train_loss_epoch, label="Train")
plt.plot(val_loss_epoch, label="val")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train/Validation loss")

plt.subplot(122)
plt.plot(train_acc_epoch, label="Train")
plt.plot(val_acc_epoch, label="val")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train/Validation Accuracy")
# Out:
# Text(0.5, 1.0, 'Train/Validation Accuracy')

# %%
mod = lenet5()
mod.load_state_dict(torch.load("hw3_best_model_pytorch.pth"))
mod = mod.to("cuda")
total_test_acc, inference_time = 0, 0
for data in test_dataloader:
    imgs,targets = data
    imgs = imgs.to("cuda")
    targets = targets.to("cuda")

    st_time = time.perf_counter()
    output = mod(imgs)
    ed_time = time.perf_counter()
    inference_time += (ed_time - st_time)
    test_correct = (output.argmax(1) == targets.argmax(1)).sum()
    total_test_acc += test_correct
print("Test top1 accuracy:{}".format(total_test_acc/len(test_dataloader.dataset)))
print("Inference time: {}s".format(inference_time))
# Out:
# Test top1 accuracy:0.08666666597127914
# Inference time: 0.0122427999995125s

# %%
summary(mod,(1,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             156
#            Sigmoid-2            [-1, 6, 28, 28]               0
#          MaxPool2d-3            [-1, 6, 14, 14]               0
#             Conv2d-4           [-1, 16, 10, 10]           2,416
#            Sigmoid-5           [-1, 16, 10, 10]               0
#          MaxPool2d-6             [-1, 16, 5, 5]               0
#            Flatten-7                  [-1, 400]               0
#             Linear-8                  [-1, 120]          48,120
#            Sigmoid-9                  [-1, 120]               0
#            Linear-10                   [-1, 84]          10,164
#           Sigmoid-11                   [-1, 84]               0
#            Linear-12                   [-1, 50]           4,250
#           Softmax-13                   [-1, 50]               0
# ================================================================
# Total params: 65,106
# Trainable params: 65,106
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.12
# Params size (MB): 0.25
# Estimated Total Size (MB): 0.37
# ----------------------------------------------------------------

# %%
# Space complexity
with torch.cuda.device(0):
  macs, params = get_model_complexity_info(mod, (1, 32, 32), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
  print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
  print('{:<30}  {:<8}'.format('Number of parameters: ', params))

# Flops
input = torch.randn(32, 1, 32, 32).to("cuda")
macs_, params = profile(mod, inputs=(input, ))
print()
print(f"FLOPs: {macs_*2/1e6} MFLOPs, params: {params/1e6} M")
# Out:
# Warning: module Sigmoid is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module Softmax is treated as a zero-op.
# Warning: module lenet5 is treated as a zero-op.
# lenet5(
#   65.11 k, 100.000% Params, 432.74 KMac, 100.000% MACs,
#   (conv1): Conv2d(156, 0.240% Params, 122.3 KMac, 28.263% MACs, 1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (sigmoid1): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   (maxpool1): MaxPool2d(0, 0.000% Params, 4.7 KMac, 1.087% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(2.42 k, 3.711% Params, 241.6 KMac, 55.830% MACs, 6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (sigmoid2): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   (maxpool2): MaxPool2d(0, 0.000% Params, 1.6 KMac, 0.370% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (linear1): Linear(48.12 k, 73.910% Params, 48.12 KMac, 11.120% MACs, in_features=400, out_features=120, bias=True)
#   (sigmoid3): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   (linear2): Linear(10.16 k, 15.611% Params, 10.16 KMac, 2.349% MACs, in_features=120, out_features=84, bias=True)
#   (sigmoid4): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   (linear3): Linear(4.25 k, 6.528% Params, 4.25 KMac, 0.982% MACs, in_features=84, out_features=50, bias=True)
#   (softmax): Softmax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, dim=1)
# )
# Computational complexity:       432.74 KMac
# Number of parameters:           65.11 k
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register count_softmax() for <class 'torch.nn.modules.activation.Softmax'>.
#
# FLOPs: 26.881856 MFLOPs, params: 0.065106 M

# %%
# print(
#     "Sparsity in conv1.weight: {:.2f}%".format(
#         100. * float(torch.sum(model.conv1.weight == 0))
#         / float(model.conv1.weight.nelement())
#     )
# )
# print(
#     "Sparsity in conv2.weight: {:.2f}%".format(
#         100. * float(torch.sum(model.conv2.weight == 0))
#         / float(model.conv2.weight.nelement())
#     )
# )
# print(
#     "Sparsity in linear1.weight: {:.2f}%".format(
#         100. * float(torch.sum(model.linear1.weight == 0))
#         / float(model.linear1.weight.nelement())
#     )
# )
# print(
#     "Sparsity in linear2.weight: {:.2f}%".format(
#         100. * float(torch.sum(model.linear2.weight == 0))
#         / float(model.linear2.weight.nelement())
#     )
# )
# print(
#     "Sparsity in linear3.weight: {:.2f}%".format(
#         100. * float(torch.sum(model.linear3.weight == 0))
#         / float(model.linear3.weight.nelement())
#     )
# )
# print(
#     "Global sparsity: {:.2f}%".format(
#         100. * float(
#             torch.sum(model.conv1.weight == 0)
#             + torch.sum(model.conv2.weight == 0)
#             + torch.sum(model.linear1.weight == 0)
#             + torch.sum(model.linear2.weight == 0)
#             + torch.sum(model.linear3.weight == 0)
#         )
#         / float(
#             model.conv1.weight.nelement()
#             + model.conv2.weight.nelement()
#             + model.linear1.weight.nelement()
#             + model.linear2.weight.nelement()
#             + model.linear3.weight.nelement()
#         )
#     )
# )
# Out:
# Sparsity in conv1.weight: 6.00%
# Sparsity in conv2.weight: 13.54%
# Sparsity in linear1.weight: 22.77%
# Sparsity in linear2.weight: 12.54%
# Sparsity in linear3.weight: 10.43%
# Global sparsity: 20.00%

# %%
# mod = lenet5()
# mod.load_state_dict(torch.load("hw3_best_model_pytorch.pth"))
# mod = mod.to("cuda")
# total_test_acc = 0
# for data in test_dataloader:
#     imgs,targets = data
#     imgs = imgs.to("cuda")
#     targets = targets.to("cuda")

#     output = mod(imgs)
#     test_correct = (output.argmax(1) == targets.argmax(1)).sum()
#     total_test_acc += test_correct
# print("Test top1 accuracy:{}".format(total_test_acc/len(test_dataloader.dataset)))
# Out:
# Test top1 accuracy:0.08888889104127884
